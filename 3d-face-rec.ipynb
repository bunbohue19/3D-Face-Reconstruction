# %% [markdown]
# # Data preparation

# %%
import os
import glob
import shutil
from tqdm import tqdm

# %%
# root = './AFDB_dataset_160_part1'
# image_paths = glob.glob(os.path.join(root, "**",  "*.jpg"), recursive=True)
# image_paths = sorted(image_paths, key=lambda x : os.path.basename(x).split('.jpg')[0])

# %%
# image_paths

# %%
# len(image_paths)

# %%
### Write to train and val dataset
# for i, img_path in enumerate(tqdm(image_paths)):
#     img_name = img_path.split("/")[-1][:-4]
#     src = img_path
#     if i <= 300000:
#         dst = f'/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train/{img_name}.jpg'
#     else:
#         dst = f'/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/val/{img_name}.jpg'
#     shutil.copy(src, dst)

# %% [markdown]
# ## Detect 5 facial landmarks of image

# %%
# tmux a -t generate_5_facial_landmarks

# !export CUDA_VISIBLE_DEVICES="0"

# !python generate_5_facial_landmarks.py \
#         --location=/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train

# %% [markdown]
# ## Remove fail image in landmarks and skin attention mask process

# %% [markdown]
# ### Train set (300k images)

# %%
# train_root = '/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train'
# image_paths = glob.glob(os.path.join(train_root, "**",  "*.jpg"), recursive=True)
# image_paths = sorted(image_paths, key=lambda x : os.path.basename(x).split('.jpg')[0])

# %%
# success_train = []
# with open('/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train_success.txt', 'r') as f:
#     for line in f.readlines():
#         success_train.append(line.split('\n')[0])
# # success_train

# fail_train = []
# for i, img_path in enumerate(tqdm(image_paths)):
#     img_name = img_path.split("/")[-1][:-4]
#     if img_name not in success_train:
#         fail_train.append(img_name)
# fail_train
# Out:
# ...
# 100%|██████████| 300001/300001 [03:01<00:00, 1656.58it/s]
# ['aduo_0015',
#  'aduo_0092',
#  'aimengmeng_0091',
#  'aimengmeng_0092',
#  'aimengmeng_0100',
#  'alan_0096',
#  'anyuexi_0253',
#  'aoquan_0188',
#  'aoquan_0203',
#  'aqiao_0013',
#  'aqiao_0028',
#  'aqiao_0083',
#  'aqiao_0123',
#  'aqiao_0165',
#  'aqiao_0179',
#  'asang_0044',
#  'axin_0054',
#  'baibaihe_0007',
#  'baien_0054',
#  'baihuizi_0101',
#  'baijingting_0004',
#  'baijingting_0030',
#  'baijingting_0034',
#  'baijingting_0063',
#  'baijingting_0067',
#  'baijingting_0078',
#  'baijingting_0129',
#  'baijingting_0139',
#  'baijingting_0156',
#  'baijingting_0175',
#  'baijingting_0186',
#  'baijingting_0192',
#  'baijugang_0013',
#  'baijugang_0056',
#  'baijugang_0059',
#  'baijugang_0063',
#  'baijugang_0087',
#  'baijugang_0143',
#  'baikeli_0068',
#  'bailing_0013',
#  'bailing_0041',
#  'bailing_0043',
#  'bailing_0047',
#  'bailing_0122',
#  'bailing_0166',
#  'bailing_0170',
#  'baishu_0166',
# ...

# %%
# len(fail_train), len(success_train), len(image_paths)
# Out:
# (1665, 298336, 300001)

# %%
# for i, img_name in enumerate(tqdm(fail_train)):
#     os.remove(f'/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train/{img_name}.jpg')
# Out:
# 100%|██████████| 1665/1665 [00:00<00:00, 1806.36it/s]

# %%
# new_train_root = '/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/train'
# image_paths = glob.glob(os.path.join(new_train_root, "**",  "*.jpg"), recursive=True)
# image_paths = sorted(image_paths, key=lambda x : os.path.basename(x).split('.jpg')[0])
# len(image_paths)
# Out:
# 298336

# %% [markdown]
# ### Validation set (10k images)

# %%
# val_root = '/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/val'
# image_paths = glob.glob(os.path.join(val_root, "**",  "*.jpg"), recursive=True)
# image_paths = sorted(image_paths, key=lambda x : os.path.basename(x).split('.jpg')[0])

# %%
# success_val = []
# with open('/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/val_success.txt', 'r') as f:
#     for line in f.readlines():
#         success_val.append(line.split('\n')[0])
# # success_val

# fail_val = []
# for i, img_path in enumerate(tqdm(image_paths)):
#     img_name = img_path.split("/")[-1][:-4]
#     if img_name not in success_val:
#         fail_val.append(img_name)
# fail_val
# Out:
# 100%|██████████| 10968/10968 [00:00<00:00, 26681.50it/s]
# ['zhouchuchu_0206',
#  'zhoudingwei_0137',
#  'zhoudongyu_0076',
#  'zhoudongyu_0170',
#  'zhouhuajian_0073',
#  'zhouhuajian_0119',
#  'zhouhuimin_0064',
#  'zhouhuimin_0191',
#  'zhoujiao_0121',
#  'zhoujiao_0122',
#  'zhoujie_0098',
#  'zhouqiqi_0141',
#  'zhouqisheng_0020',
#  'zhoushen_0012',
#  'zhoushen_0110',
#  'zhoushen_0117',
#  'zhoushen_0168',
#  'zhouweitong_0063',
#  'zhouweitong_0146',
#  'zhouxianxin_0003',
#  'zhouxianxin_0062',
#  'zhouxuan_0002',
#  'zhouxuan_0043',
#  'zhouxuan_0067',
#  'zhouxuan_0072',
#  'zhouxuan_0115',
#  'zhouyanhong1_0023',
#  'zhouyanhong1_0037',
#  'zhouyanhong1_0061',
#  'zhouyanhong_0004',
#  'zhudan_0065',
#  'zhudan_0100',
#  'zhudan_0140',
#  'zhuoyiting_0161',
#  'zhuyaqiong_0007',
#  'zhuyawen_0005',
#  'zhuyawen_0118',
#  'zhuyilong_0228',
#  'zhuyin_0094',
#  'zhuyuanbing_0006',
#  'zhuyuanbing_0011',
#  'zhuyuanbing_0030',
#  'zhuyuchen_0176',
#  'zufeng_0255',
# ...

# %%
# len(fail_val), len(success_val), len(image_paths)
# Out:
# (50, 10918, 10968)

# %%
# for i, img_name in enumerate(tqdm(fail_val)):
#     os.remove(f'/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/val/{img_name}.jpg')
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 1350.26it/s]

# %%
# new_val_root = '/mnt/4TData/vuquang/3d-face-rec/Deep3DFaceRecon_pytorch/datasets/12-05-2024/val'
# image_paths = glob.glob(os.path.join(new_val_root, "**",  "*.jpg"), recursive=True)
# image_paths = sorted(image_paths, key=lambda x : os.path.basename(x).split('.jpg')[0])
# len(image_paths)
# Out:
# 10918

# %% [markdown]
# ## Generate 68 landmarks and skin attention mask for images

# %%
# python data_preparation.py --data_root=./datasets/02-05-2024 --img_folder=train --mode=train
# python data_preparation.py --data_root=./datasets/02-05-2024 --img_folder=val --mode=val

# %% [markdown]
# ## Training (12/05/2024)

# %%
# python train.py --name=12-05-2024 \
#                 --gpu_ids=0 \
#                 --batch_size=32 \
#                 --num_threads=8 \
#                 --preprocess=shift_scale_rot_flip \
#                 --use_aug=True \
#                 --batch_size_val=32 \
#                 --display_freq=1000 \
#                 --print_freq=100 \
#                 --save_latest_freq=5000 \
#                 --save_epoch_freq=1 \
#                 --evaluation_freq=5000 \
#                 --n_epochs=20 \
#                 --lr=0.0001 \
